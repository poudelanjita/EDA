# %%
import pandas as pd
import numpy as np
import seaborn  as sns
import matplotlib.pyplot as plt


filepath=r"C:\Users\DELL\OneDrive\Desktop\student.csv"
df=pd.read_csv(filepath, encoding='latin1')
               
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196           2
# ...

# %%
#countplot
sns.countplot(data=df, x='Gender')
df['GradeClass'].value_counts()
# Out:
# GradeClass
# 4    1211
# 3     414
# 2     391
# 1     269
# 0     107
# Name: count, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%0.3f')
# Out:
# <Axes: ylabel='count'>

# %%
#histogram
plt.hist(df['Absences'])
# Out:
# (array([221., 231., 265., 199., 269., 247., 259., 240., 254., 207.]),
#  array([ 0. ,  2.9,  5.8,  8.7, 11.6, 14.5, 17.4, 20.3, 23.2, 26.1, 29. ]),
#  <BarContainer object of 10 artists>)

# %%
#distplot
sns.distplot(df['Absences'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_480\356547600.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Absences'])
# C:\anacondaa\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Absences', ylabel='Density'>

# %%
#boxplot
sns.boxplot(df['Absences'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
#scatter plot
sns.scatterplot(x='Absences', y='GPA', hue='ParentalSupport', style='Ethnicity' ,size='Music', data=df)
# Out:
# <Axes: xlabel='Absences', ylabel='GPA'>

# %%
sns.barplot(x='Tutoring',y='GPA',hue='ParentalSupport',data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.barplot(x='Tutoring',y='GPA',hue='ParentalSupport',data=df)
#
# File C:\anacondaa\Lib\site-packages\seaborn\categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File C:\anacondaa\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
#boxplot
sns.boxplot(x='Tutoring',y='GPA',hue='ParentalSupport',data=df)
# Out:
# <Axes: xlabel='Tutoring', ylabel='GPA'>

# %%
#Displot
sns.distplot(df[df['Tutoring']==0]['Age'],hist=False)
sns.distplot(df[df['Tutoring']==1]['Age'],hist=False)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_480\3262288657.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tutoring']==0]['Age'],hist=False)
# C:\anacondaa\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\AppData\Local\Temp\ipykernel_480\3262288657.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
#heatmap
sns.heatmap(pd.crosstab(df['ParentalSupport'],df['Tutoring']))
# Out:
# <Axes: xlabel='Tutoring', ylabel='ParentalSupport'>

# %%
df.groupby('ParentalSupport').mean()['Tutoring']*100
# Out:
# ParentalSupport
# 0    28.773585
# 1    30.879346
# 2    30.540541
# 3    29.555237
# 4    30.314961
# Name: Tutoring, dtype: float64

# %%
sns.lineplot(x='GradeClass',y='Tutoring',data=df)
# Out:
# C:\anacondaa\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\anacondaa\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='GradeClass', ylabel='Tutoring'>

# %%
sns.heatmap(df.pivot_table(values='GradeClass',index='Gender',columns='Tutoring'))
# Out:
# <Axes: xlabel='Tutoring', ylabel='Gender'>

# %%
sns.clustermap(df.pivot_table(values='GradeClass',index='Gender',columns='Tutoring'))
